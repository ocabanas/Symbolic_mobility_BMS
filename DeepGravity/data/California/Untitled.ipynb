# %%
import pandas as pd

# %%
pd.read_csv('train_set.csv')['name_o'].tolist()
# Out:
# ['Monterey Park',
#  'Woodland',
#  'Pasadena',
#  'Industry',
#  'El Dorado Hills',
#  'Artesia',
#  'Upland',
#  'Lodi',
#  'Monrovia',
#  'Menlo Park',
#  'La Habra',
#  'Mountain View Acres',
#  'Casa Conejo',
#  'Hawthorne',
#  'Irvine',
#  'Bell',
#  'Rossmoor',
#  'Concord',
#  'Rosedale',
#  'Mission Viejo',
#  'Monterey Park',
#  'Aliso Viejo',
#  'Chino Hills',
#  'Chula Vista',
#  'Commerce',
#  'Sacramento',
#  'Eastvale',
#  'Pinole',
#  'Butte Creek Canyon',
#  'Whittier',
#  'Irvine',
#  'Encinitas',
#  'Downey',
#  'Hercules',
#  'Carson',
#  'Valinda',
#  'Dinuba',
#  'Suisun City',
#  'Altadena',
#  'San Buenaventura (Ventura)',
#  'Menifee',
#  'West Rancho Dominguez',
#  'Oak View',
#  'March ARB',
#  'Aliso Viejo',
#  'Monrovia',
#  'Chino',
#  'South Pasadena',
#  'Monrovia',
#  'Seaside',
#  'Elverta',
#  'South San Francisco',
#  'Downey',
#  'Garden Grove',
#  'San Leandro',
#  'La Mirada',
#  'Rohnert Park',
#  'Placentia',
#  'Richmond',
# ...
