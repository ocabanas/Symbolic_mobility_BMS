# %%
import pandas as pd
from pickle import dump, load
import copy
import geopandas as geo

# %%
list_states = pd.read_pickle('list_states_dataframes_2022_11_02-02_53_58(1).pkl')

# %%
a
# Out:
#                    name_o          name_d  total_pop_flow          d  \
# 0                Altamont          Albany          1213.0  19.728926
# 3                Altamont     Schenectady           544.0  13.876745
# 4                Altamont  East Glenville            99.0  19.605706
# 6                Altamont        Westmere          1164.0  13.220771
# 118              Lockport  East Rochester            90.0  98.269409
# ...                   ...             ...             ...        ...
# 22771  University Gardens      West Hills           159.0  25.245491
# 22772          Williamson          Geneva            79.0  43.247404
# 22775          Williamson         Palmyra           277.0  18.442643
# 22776          Williamson  East Rochester           158.0  27.489255
# 22783          Williamson     Irondequoit           237.0  31.447070
#
#                 s     area_o     area_d    m_o    m_d  food_point_o  ...  \
# 0        148152.0   3.279144  55.435357   1675  99224             6  ...
# 3         33369.0   3.279144  27.991725   1675  67047             6  ...
# 4        136256.0   3.279144  26.056067   1675  11896             6  ...
# 6         25809.0   3.279144   8.208195   1675   7560             6  ...
# 118     1085069.0  21.755323   3.405735  20876   6334            14  ...
# ...           ...        ...        ...    ...    ...           ...  ...
# 22771  10582822.0   1.375443  12.708747   4358   5385             2  ...
# 22772    381131.0   9.946210  10.914565   2418  12812             4  ...
# 22775      2215.0   9.946210   3.488424   2418   3305             4  ...
# 22776     29678.0   9.946210   3.405735   2418   6334             4  ...
# 22783     38183.0   9.946210  38.890209   2418  51043             4  ...
#
#        commercial_landuse_d  retail_point_d  retail_poly_d  school_point_d  \
# 0                         5             280       0.604190             175
# 3                         3             157       0.331886              81
# 4                         1              68       0.269949               7
# 6                         0              40       0.571592               4
# 118                       0             180       0.316131              12
# ...                     ...             ...            ...             ...
# 22771                     0              82       0.406436               8
# 22772                     3              30       0.019070              35
# 22775                     0              75       0.012795               4
# 22776                     0             180       0.316131              12
# 22783                     2              59       0.271477              43
#
#        school_poly_d  transport_point_d  transport_poly_d  \
# 0           5.663061               1030          2.631899
# 3           1.200517                237          0.678408
# 4           0.016993                 62          3.366000
# 6           0.254887                 30          0.270485
# 118         0.242698                 89          0.216251
# ...              ...                ...               ...
# 22771       0.315799                 20          0.049361
# 22772       1.320604                158          0.117565
# 22775       0.027321                  5          0.008246
# 22776       0.242698                 89          0.216251
# 22783       0.982639                 80          0.299171
#
#        entertainment_point_d  entertainment_poly_d          sk
# 0                        659             16.926204    175163.0
# 3                        259              4.355601     55782.0
# 4                         39              1.617063    156545.0
# 6                         18              8.091757     26436.0
# 118                      109              0.309692   1026085.0
# ...                      ...                   ...         ...
# 22771                     43              7.620000  10731889.0
# 22772                    115              1.313142    260963.0
# 22775                     29              0.546851         0.0
# 22776                    109              0.309692     13885.0
# 22783                    147              6.843724     22557.0
#
# [6101 rows x 46 columns]

# %%
list_states = pd.read_pickle('list_states_dataframes_2022_11_02-02_53_58(1).pkl')
list_folders = ['NewYork', 'Massachusetts', 'California', 'Florida', 'Washington', 'Texas']

for i, f in zip(list_states, list_folders):
    
    frame = copy.copy(i[['name_o', 'name_d', 'total_pop_flow']])
    frame.rename(columns={'name_o':'residence', 'name_d':'workplace', 'total_pop_flow':'commuters'}, inplace=True)
    frame.to_csv('%s/flows.csv'%f, index=False)
    
    frame = copy.copy(i)
    columns = frame.columns
    to_keep = [x for x in columns if x[-2:] == '_o']
    frame = frame[to_keep]
    cities = frame.name_o.unique()
    features = frame[frame.name_o==cities[0]].iloc[0]
    
    for city in cities[1:]:
        sn = frame[frame.name_o==city].iloc[0]
        features = pd.concat([features, sn], axis=1)
        
    renaming = {x : x[:-2] for x in to_keep}
    features = features.transpose().rename(columns=renaming)
    
    frame = copy.copy(i)
    cities2 = [x for x in frame.name_d.unique() if x not in cities]
    
    if len(cities2) >  0:
        
        columns = frame.columns
        to_keep = [x for x in columns if x[-2:] == '_d']
        frame = frame[to_keep]
        features2 = frame[frame.name_d==cities2[0]].iloc[0]
        
        if len(cities2)>1:
            for city in cities2[1:]:
                sn = frame[frame.name_d==city].iloc[0]
                features2 = pd.concat([features2, sn], axis=1)

        renaming = {x : x[:-2] for x in to_keep}
        features2 = features2.transpose().rename(columns=renaming)

        features = pd.concat([features, features2])

    features[['name', 'm', 'area']].to_csv('%s/city2pop.csv'%f, index=False)
    
    features.drop(columns=['area', 'm', 'entertainment_point', 'entertainment_poly'], inplace=True)
    features['other_road_line'] = [0.0]*len(features)
    features['residential_line'] = [0.0]*len(features)
    features = features.reindex(columns=['name','commercial_landuse','food_point', 'food_poly', 'health_point',
                                                         'health_poly', 'industrial_landuse', 'main_road_line',
                                                          'natural_landuse', 'other_road_line', 'residential_landuse',
                                                          'residential_line', 'retail_landuse', 'retail_point', 'retail_poly',
                                                          'school_point', 'school_poly', 'transport_point', 'transport_poly'])
    
    features.to_pickle('%s/features.pkl'%f)
# Out:
# Hi Pal!
# 642
# Hi Pal!
# ['Avenal', 'Tehachapi']
#            name       area      m food_point food_poly health_point  \
# 4584     Avenal  50.459974  13696          0       0.0            0
# 9705  Tehachapi   26.56314  12939         29  0.000584            3
#
#      health_poly industrial_landuse main_road_line natural_landuse  ...  \
# 4584         0.0                 13      356.42793               0  ...
# 9705    0.063938                 23     215.374041               0  ...
#
#      retail_landuse commercial_landuse retail_point retail_poly school_point  \
# 4584              0                  3            0         0.0           23
# 9705              2                 21           28    0.154746           10
#
#      school_poly transport_point transport_poly entertainment_point  \
# 4584    0.228946              13       0.357429                  12
# 9705    0.501927              53       0.725184                  37
#
#      entertainment_poly
# 4584           0.102051
# 9705           0.240299
#
# [2 rows x 21 columns]

# %%
for f in list_folders:
    
    city2pop = pd.read_csv('%s/city2pop.csv'%f)
    centroids = geo.read_file('%s/tl.shp'%f)
    city2meta = {}
    
    for r, row in city2pop.iterrows():
        
        name = row['name']
        centroid = centroids[centroids.NAME==name].geometry.centroid
        lat, long = centroid.y.values[0], centroid.x.values[0]
        
        city2meta[name] = {'population':row.m, 'area': row.area, 'centroid':[lat, long]}
        
    with open('%s/city2meta.pkl'%f, 'wb') as out:
        dump(city2meta, out)
# Out:
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# ...
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
# /tmp/ipykernel_33890/1587096421.py:10: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centroid = centroids[centroids.NAME==name].geometry.centroid
